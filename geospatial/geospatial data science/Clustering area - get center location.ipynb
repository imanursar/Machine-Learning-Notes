# %% [markdown]
# # Library

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar import big_data, fe, describe
from ursar_map import maps
from ursar_optimization import optimization
from ursar_statistic import statistic
from ursar_clustering import clustering
# %reload_ext autoreload

# %% [markdown]
# # Params

# %%
province_name = "NUSA TENGGARA BARAT"

# %%
root_path = ''

# %%
result_geocode = gpd.read_parquet(f"{root_path}/data/result_geocode_farmers.parquet")

# %%
farmers_agg_trx = pd.read_parquet(f"{root_path}/data/farmers_agg_trx.parquet")

# %% [markdown]
# # pre-processing

# %%
merge_1 = pd.merge(result_geocode[["lead_id","latitude","longitude","geometry"]], farmers_agg_trx[["lead_id","highest_product_kg","total_kg"]], on = "lead_id", how = "left")

# %% [markdown]
# # Clustering

# %%
model_1,labels_1 = clustering.cluster_core(merge_1[['latitude','longitude']],types='kmeans',k=5,result=True,context=False)

# %%
model_2,labels_2 = clustering.cluster_core(merge_1[['latitude','longitude','total_kg']],types='kmeans',k=5,result=True,context=False)

# %%
model_3,labels_3 = clustering.cluster_core(merge_1[['latitude','longitude','highest_product_kg']],types='kmeans',k=5,result=True,context=False)

# %% [markdown]
# ## result model 1

# %%
m = maps.map_marker_fol_plot(merge_1[['lead_id',"longitude","latitude"]],shape=None,col_list=["latitude","longitude"],
                         center_coor=[np.mean(merge_1['latitude']), np.mean(merge_1['longitude'])],
                         marker='point',tip=["lead_id","latitude","longitude"],
                         cluster=True,tiles='OpenStreetMap',zoom=9,radius=10,
                         geometry=None,route=None,title=None,skip_first=False)


for i in range(len(model_1.cluster_centers_)):
    folium.CircleMarker((model_1.cluster_centers_[i][0],model_1.cluster_centers_[i][1]), radius=20,tooltip=f'{i}', weight=2, color='red', fill_color='red', fill_opacity=.5).add_to(m)
m.save(f"{root_path}/map_result/lombok_cluster_1.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## result model 2

# %%
m = maps.map_marker_fol_plot(merge_1[['lead_id',"longitude","latitude"]],shape=None,col_list=["latitude","longitude"],
                         center_coor=[np.mean(merge_1['latitude']), np.mean(merge_1['longitude'])],
                         marker='point',tip=["lead_id","latitude","longitude"],
                         cluster=True,tiles='OpenStreetMap',zoom=9,radius=10,
                         geometry=None,route=None,title=None,skip_first=False)


for i in range(len(model_2.cluster_centers_)):
    folium.CircleMarker((model_2.cluster_centers_[i][0],model_2.cluster_centers_[i][1]), radius=20,tooltip=f'{i}', weight=2, color='red', fill_color='red', fill_opacity=.5).add_to(m)
m.save(f"{root_path}/map_result/lombok_cluster_2.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## result model 3

# %%
m = maps.map_marker_fol_plot(merge_1[['lead_id',"longitude","latitude"]],shape=None,col_list=["latitude","longitude"],
                         center_coor=[np.mean(merge_1['latitude']), np.mean(merge_1['longitude'])],
                         marker='point',tip=["lead_id","latitude","longitude"],
                         cluster=True,tiles='OpenStreetMap',zoom=9,radius=10,
                         geometry=None,route=None,title=None,skip_first=False)


for i in range(len(model_3.cluster_centers_)):
    folium.CircleMarker((model_3.cluster_centers_[i][0],model_3.cluster_centers_[i][1]), radius=20,tooltip=f'{i}', weight=2, color='red', fill_color='red', fill_opacity=.5).add_to(m)
m.save(f"{root_path}/map_result/lombok_cluster_3.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
