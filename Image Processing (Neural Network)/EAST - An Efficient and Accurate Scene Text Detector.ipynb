# %% [markdown]
# # Library

# %%
from imutils.object_detection import non_max_suppression
import numpy as np
import argparse
import time
import cv2

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar import describe,fe,image_processing

# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # EXAMPLE 1

# %%
image_name = f"E:/gitlab/project_on_python/image_processing/images/car_wash.png"
east = f"E:/gitlab/project_on_python/image_processing/frozen_east_text_detection.pb"

# %%
image_processing.text_detection(image_name,east)
# Out:
# origin shape
# width= 600, height= 338
# reshape shape
# width= 640, height= 320
# [INFO] loading EAST text detector...
# [INFO] text detection took 0.377000 seconds

# %% [markdown]
# # EXAMPLE 2

# %%
image_name = f"E:/gitlab/project_on_python/image_processing/images/lebron_james.jpg"
east = f"E:/gitlab/project_on_python/image_processing/frozen_east_text_detection.pb"

# %%
image_processing.text_detection(image_name,east)
# Out:
# origin shape
# width= 600, height= 500
# reshape shape
# width= 640, height= 320
# [INFO] loading EAST text detector...
# [INFO] text detection took 0.364369 seconds

# %%
image_name = f"E:/gitlab/project_on_python/image_processing/images/sign.jpg"
east = f"E:/gitlab/project_on_python/image_processing/frozen_east_text_detection.pb"

# %%
image_processing.text_detection(image_name,east)
# Out:
# origin shape
# width= 463, height= 400
# reshape shape
# width= 640, height= 320
# [INFO] loading EAST text detector...
# [INFO] text detection took 0.426980 seconds
