# %% [markdown]
# # Library

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar import describe,fe,image_processing
# %reload_ext autoreload

# %% [markdown]
# # Face Swap

# %%
image_processing.face_swap(image_source=r'E:\gitlab\machine-learning\dataset\images\Hillary.jpg',
                           image_match=r'E:\gitlab\machine-learning\dataset\images\Trump.jpg'
                          ,save=False,is_video=False)

# %% [markdown]
# # Face swap with video

# %%
image_processing.face_swap(image_source=r'E:\gitlab\machine-learning\dataset\images\house (2).jpg',
                           image_match=r'E:\gitlab\machine-learning\dataset\images\Trump.jpg'
                          ,save=False,is_video=True)
