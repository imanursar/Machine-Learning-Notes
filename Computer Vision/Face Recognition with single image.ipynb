# %% [markdown]
# # Library

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar_image_processing import image_processing
# %reload_ext autoreload

# %% [markdown]
# # Face Recognition

# %%
image_processing.face_recognition(image_data=r'E:\gitlab\machine-learning\dataset\images\trump-modi-unknown.jpg',
                                  image_match=r'E:\gitlab\machine-learning\dataset\images\trump (3).jpg',
                                  labels=['trump'])

# %% [markdown]
# # Live Video

# %%
image_processing.video_face_recognition_simple(
                                  types='cam',image_data='',
                                  image_match=r'E:\gitlab\machine-learning\dataset\images\trump (3).jpg',
                                  labels=['trump'], 
                                  model='hog',sampling_face=2,resize=True)

# %% [markdown]
# # from video

# %%
image_processing.video_face_recognition_simple(
                                  types='video',
                                  image_data=r'E:\gitlab\machine-learning\dataset\images\modi.mp4',
                                  image_match=r'E:\gitlab\machine-learning\dataset\images\modi.jpg',
                                  labels=['modi'], 
                                  model='hog',sampling_face=2,resize=True)
