# %% [markdown]
# # Library

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar_image_processing import image_processing
# %reload_ext autoreload

# %% [markdown]
# # Face Landmark

# %%
image_processing.face_landmark(image_data=r'E:\gitlab\machine-learning\dataset\images\trump-modi-unknown.jpg')

# %% [markdown]
# # live Video

# %%
image_processing.video_face_landmark(image_data=r'E:\gitlab\machine-learning\dataset\images\trump-modi-unknown.jpg',
                                      types='cam')
