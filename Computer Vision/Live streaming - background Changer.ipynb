# %% [markdown]
# # Library

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar_image_processing import image_processing
# %reload_ext autoreload

# %% [markdown]
# # background changer

# %% [markdown]
# ## at Image

# %%
image_processing.background_changer(types='image',
                                    image_data=r'E:\gitlab\machine-learning\dataset\images\jason.jpg',
                                    image_background=r'E:\gitlab\machine-learning\dataset\images\Sunflowers.jpg'
                                    ,method='white',thresh=0.9, blur = 95)

# %%
image_processing.background_changer(types='image',
                                    image_data=r'E:\gitlab\machine-learning\dataset\images\jason.jpg',
                                    image_background=r'E:\gitlab\machine-learning\dataset\images\Sunflowers.jpg'
                                    ,method='blur',thresh=0.9, blur = 95)

# %%
image_processing.background_changer(types='image',
                                    image_data=r'E:\gitlab\machine-learning\dataset\images\jason.jpg',
                                    image_background=r'E:\gitlab\machine-learning\dataset\images\Sunflowers.jpg'
                                    ,method='desature',thresh=0.9, blur = 95)

# %%
image_processing.background_changer(types='image',
                                    image_data=r'E:\gitlab\machine-learning\dataset\images\jason.jpg',
                                    image_background=r'E:\gitlab\machine-learning\dataset\images\Sunflowers.jpg'
                                    ,method='transparent',thresh=0.9, blur = 95)

# %%
image_processing.background_changer(types='image',
                                    image_data=r'E:\gitlab\machine-learning\dataset\images\jason.jpg',
                                    image_background=r'E:\gitlab\machine-learning\dataset\images\tobago.jpg'
                                    ,method='image',thresh=0.9, blur = 95)
# Out:
# hello

# %% [markdown]
# ## from Cam

# %%
image_processing.background_changer(types='cam_b_image',
                                    image_data=r'E:\gitlab\machine-learning\dataset\images\jason.jpg',
                                    image_background=r'E:\gitlab\dataset\images\back'
                                    ,method='image',thresh=0.9, blur = 95)

# %%
image_processing.background_changer(types='cam_b_image',
                                    image_data=r'E:\gitlab\machine-learning\dataset\images\jason.jpg',
                                    image_background=r'E:\gitlab\machine-learning\dataset\images\back'
                                    ,method='blur',thresh=0.9, blur = 95,reverse=True)

# %%
image_processing.background_changer(types='cam_b_image',
                                    image_data=r'E:\gitlab\machine-learning\dataset\images\jason.jpg',
                                    image_background=r'E:\gitlab\machine-learning\dataset\images\back'
                                    ,method='desature',thresh=0.9, blur = 95,reverse=False)

# %%
image_processing.background_changer(types='cam_b_image',
                                    image_data=r'E:\gitlab\machine-learning\dataset\images\jason.jpg',
                                    image_background=r'E:\gitlab\machine-learning\dataset\images\back'
                                    ,method='black',thresh=0.9, blur = 95,reverse=True)

# %% [markdown]
# ## from cam with  video

# %%
image_processing.background_changer(types='cam_b_video',
                                    image_data=r'E:\gitlab\machine-learning\dataset\images\jason.jpg',
                                    image_background=r'E:\gitlab\machine-learning\dataset\images\test_video.mp4'
                                    ,method='image',thresh=0.3, blur = 95,reverse=False)

# %% [markdown]
# ## live streaming

# %%
image_processing.background_changer_streaming(types='cam_b_image',
                                              image_background=r'E:\gitlab\machine-learning\dataset\images\back\Sunflowers.jpg',
                                              method='image',thresh=0.9, 
                                              blur = 95,reverse=False,
                                              resolution=[640,360],fps=60)
# Out:
# Using virtual camera: OBS Virtual Camera
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 image_processing.background_changer_streaming(types='cam_b_image',
#       2                                               image_background=r'E:\gitlab\machine-learning\dataset\images\back\Sunflowers.jpg',
#       3                                               method='image',thresh=0.9,
#       4                                               blur = 95,reverse=False,
#       5                                               resolution=[640,360],fps=60)
#
# File E:\gitlab\custom-script\script\ursar_image_processing.py:4260, in image_processing.background_changer_streaming(types, image_data, image_background, method, thresh, blur, reverse, resolution, fps)
#    4257             ret, frame = cap.read()
# ...

# %%
image_processing.background_changer_streaming(types='cam_b_video',
                                              image_background=r'E:\gitlab\machine-learning\dataset\images\test_video.mp4',
                                              method='image',thresh=0.9, 
                                              blur = 95,reverse=False,
                                              resolution=[640,360],fps=60)
# Out:
# Using virtual camera: OBS Virtual Camera
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 image_processing.background_changer_streaming(types='cam_b_video',
#       2                                               image_background=r'E:\gitlab\machine-learning\dataset\images\test_video.mp4',
#       3                                               method='image',thresh=0.9,
#       4                                               blur = 95,reverse=False,
#       5                                               resolution=[640,360],fps=60)
#
# File E:\gitlab\custom-script\script\ursar_image_processing.py:4272, in image_processing.background_changer_streaming(types, image_data, image_background, method, thresh, blur, reverse, resolution, fps)
#    4270 print(f'Using virtual camera: {cam.device}')
#    4271 while True:
# ...
