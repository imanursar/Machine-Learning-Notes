# %% [markdown]
# # Library

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar import image_processing
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Face detection

# %% [markdown]
# ## collect the data

# %%
image_processing.video_face_recognition(types="collect image",user_name='ursar',
                                        n_train_data=1000,img_size=300)
# Out:
# E:\gitlab\machine-learning\image processing\open cv\faces\ursar
# create folder at E:\gitlab\machine-learning\image processing\open cv\faces\ursar
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# ...

# %% [markdown]
# ## training

# %%
image_processing.video_face_recognition(types="training",user_name='ursar',
                                        n_train_data=100,img_size=200,saved_model='saved_model')
# Out:
# Model trained sucessefully

# %% [markdown]
# ## prediction

# %%
image_processing.video_face_recognition(types="recognition",user_name='ursar',
                                        n_train_data=100,img_size=200,saved_model='saved_model')

# %% [markdown]
# # explain

# %% [markdown]
#     1. record n images of face using HAAR cascade face detection
#     2. normalize by gray scale and resize to mxm image
#     3. create an array labels for record images
#     4. training data
#         a. save model
#     6. prediction
#         a. Extract Face from Webcam using the HAAR Cascade Face Detector
#         b. normalize by gray scale and resize to mxm image
#         c. pass face to model predictor to get label and confidence value

# %% [markdown]
# # model

# %% [markdown]
# Local Binary Patterns Histograms
#
# Uses local feature extraction while persevering spatial relationships.
# It divides faces into cells and then compares each cell to face being
# classified. It then produces a histogram showing the matching values of an area.
