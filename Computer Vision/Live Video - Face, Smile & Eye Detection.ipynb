# %% [markdown]
# ### Tuning Cascade Classifiers
#
# *ourClassifier*.**detectMultiScale**(input image, **Scale Factor** , **Min Neighbors**)
#
# - **Scale Factor**
# Specifies how much we reduce the image size each time we scale. E.g. in face detection we typically use 1.3. This means we reduce the image by 30% each time it’s scaled. Smaller values, like 1.05 will take longer to compute, but will increase the rate of detection.
#
#
#
# - **Min Neighbors**
# Specifies the number of neighbors each potential window should have in order to consider it a positive detection. Typically set between 3-6.
# It acts as sensitivity setting, low values will sometimes detect multiples faces over a single face. High values will ensure less false positives, but you may miss some faces.

# %% [markdown]
# # Library

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar_image_processing import image_processing
# %reload_ext autoreload

# %% [markdown]
# # Face & Eye Detection

# %% [markdown]
# ## image

# %% [markdown]
# ### version 1

# %%
image_processing.face_detection(image_data=r'E:\gitlab\machine-learning\dataset\images\Trump.jpg'
               ,edges=0,version=1)

# %% [markdown]
# ### version 2

# %%
image_processing.face_detection(image_data=r'E:\gitlab\machine-learning\dataset\images\trump (2).jpg'
               ,version=2,model='hog',sampling_face=1)

# %%
image_processing.face_detection(image_data=r'E:\gitlab\machine-learning\dataset\images\trump-modi.jpg'
               ,version=2,model='hog',sampling_face=1)

# %%
image_processing.face_detection(image_data=r'E:\gitlab\machine-learning\dataset\images\Hillary.jpg'
               ,edges=0,version=1)

# %% [markdown]
# ## live video type

# %% [markdown]
# ### version 1

# %%
image_processing.video_face_detection(edges=0,version=1)

# %% [markdown]
# ### version 2

# %%
image_processing.video_face_detection(edges=0,version=2,model='hog',sampling_face=1)

# %% [markdown]
# ### with blur face

# %%
image_processing.video_face_detection(edges=0,version=1,blur=True)

# %%
image_processing.video_face_detection(edges=0,version=2,model='hog',sampling_face=1,blur=True)

# %% [markdown]
# ## video type

# %%
image_processing.video_face_detection(path=r'E:\gitlab\machine-learning\dataset\images\test_video.mp4',
                                      edges=0,version=2,model='hog',sampling_face=2)

# %%
#
