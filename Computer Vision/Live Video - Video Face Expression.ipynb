# %% [markdown]
# # Library

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar_image_processing import image_processing
# %reload_ext autoreload

# %% [markdown]
# # Video Face Expression

# %% [markdown]
# ## Live video

# %%
image_processing.video_face_expression(
            structure_path=r'E:\gitlab\machine-learning\dataset\images_template\face_detection\facial_expression_model_structure.json',
            weight_path=r'E:\gitlab\machine-learning\dataset\images_template\face_detection\facial_expression_model_weights.h5',
            labels=['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral'],
            model='hog',sampling_face=2,resize=True)

# %% [markdown]
# ## video

# %%
image_processing.video_face_expression(
            path = r'E:\gitlab\machine-learning\dataset\images\test_video.mp4',
            structure_path=r'E:\gitlab\machine-learning\dataset\images_template\face_detection\facial_expression_model_structure.json',
            weight_path=r'E:\gitlab\machine-learning\dataset\images_template\face_detection\facial_expression_model_weights.h5',
            labels=['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral'],
            model='hog',sampling_face=2,resize=True)

# %% [markdown]
# ## from Image

# %%
image_processing.detect_face_expression(
            image_data = r'E:\gitlab\machine-learning\dataset\images\trump-modi-unknown.jpg',
            structure_path=r'E:\gitlab\machine-learning\dataset\images_template\face_detection\facial_expression_model_structure.json',
            weight_path=r'E:\gitlab\machine-learning\dataset\images_template\face_detection\facial_expression_model_weights.h5',
            labels=['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral'],
            model='hog',sampling_face=2)
