# %% [markdown]
# # Library

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar import describe,fe,image_processing
# %reload_ext autoreload

# %% [markdown]
# # circle detection

# %%
image_processing.circle_detection(r'E:\gitlab\machine-learning\dataset\images\blobs.jpg')
