# %% [markdown]
# # Library

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar import describe,fe,image_processing
# %reload_ext autoreload

# %% [markdown]
# #  Histogram of Oriented Gradients

# %% [markdown]
# ## version 1

# %%
image_processing.hist_oriented_grad(r'E:\gitlab\machine-learning\dataset\images\elephant.jpg',
                                    cell=8,block=2,color_bins = 5, version=1)

# %% [markdown]
# ## version 2

# %%
image_processing.hist_oriented_grad(r'E:\gitlab\machine-learning\dataset\images\elephant.jpg',
                                    cell=8,block=2,color_bins = 5, version=2)
