# %% [markdown]
# # Library

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar import describe,fe,image_processing
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # line detection

# %%
result,lines = image_processing.line_detection(r'E:\gitlab\machine-learning\dataset\images\soduku.jpg',threshold=220)

# %% [markdown]
# ## line detection proba

# %%
result,lines = image_processing.line_detection(r'E:\gitlab\machine-learning\dataset\images\soduku.jpg',
                                               threshold=200,proba=True)

# %% [markdown]
# ## Fail detection

# %%
result = image_processing.line_detection(r'E:\gitlab\machine-learning\dataset\images\bottlecaps.jpg',
                                               threshold=300,proba=False,is_circle=True)
