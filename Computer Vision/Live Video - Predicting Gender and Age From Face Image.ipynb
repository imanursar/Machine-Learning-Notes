# %% [markdown]
# # Library

# %%
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar_image_processing import image_processing
# %reload_ext autoreload

# %% [markdown]
# # Face to age and gender detection

# %% [markdown]
# ## From Image

# %%
image_processing.age_gender_detection(image_data=r'E:\gitlab\machine-learning\dataset\images\trump-modi.jpg',
                                      model='hog',sampling_face=1)

# %% [markdown]
# ## from Live video

# %%
image_processing.video_age_gender_detection(image_data="",
                                      types = 'cam',model='hog',sampling_face=1)
