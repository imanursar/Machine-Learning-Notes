# %%
# Import module for data manipulation
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar import clustering

# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load the data
df = pd.read_csv(r'E:\gitlab\machine-learning\dataset\Wholesale customers data.csv')
# The dimension of data
# Print the first 5 rows
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
clustering.scoring_cluster(df,'gap',maxClusters=30)

# %%
clustering.scoring_cluster(df,'elbow',maxClusters=30)

# %%
clustering.scoring_cluster(df,'silhouette',maxClusters=30)

# %%
clustering.scoring_cluster(df,'sd',maxClusters=11)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.5115333882980367
# For n_clusters = 3 The average silhouette_score is : 0.4783511411368133
# For n_clusters = 4 The average silhouette_score is : 0.3866313675434283
# For n_clusters = 5 The average silhouette_score is : 0.3832957495230123
# For n_clusters = 6 The average silhouette_score is : 0.3201285196683464
# For n_clusters = 7 The average silhouette_score is : 0.34339687681042913
# For n_clusters = 8 The average silhouette_score is : 0.3429292479996834
# For n_clusters = 9 The average silhouette_score is : 0.31174105019671416
# For n_clusters = 10 The average silhouette_score is : 0.29766664475146376

# %%
clustering.scoring_cluster(df,'ch',maxClusters=30)

# %%
ass, asss = clustering.scoring_clustering(df,'db',maxClusters=30)

# %%
clustering.scoring_cluster(df,'dendrogram',maxClusters=30)

# %%
score = clustering.scoring_cluster(df,'bic',maxClusters=30)
