# %% [markdown]
# # Autoencoders Come from Artificial Neural Network

# %% [markdown]
# An autoencoder is a special type of neural network that copies the input values to the output values. It does not require the target variable like the conventional Y, thus it is categorized as unsupervised learning.
#
# Indeed, we are not so much interested in the output layer. We are interested in the hidden core layer. If the number of neurons in the hidden layers is less than that of the input layers, the hidden layers will extract the essential information of the input values.
#
# Indeed, we are not so much interested in the output layer. We are interested in the hidden core layer. If the number of neurons in the hidden layers is less than that of the input layers, the hidden layers will extract the essential information of the input values.
#
# If the number of neurons in the hidden layers is more than those of the input layers, the neural network will be given too much capacity to learn the data. In an extreme case, it could just simply copy the input to the output values, including noises, without extracting any essential information.

# %% [markdown]
# The encoding process compresses the input values to get to the core layer. The decoding process reconstructs the information to produce the outcome. The decoding process mirrors the encoding process in the number of hidden layers and neurons. Most practitioners just adopt this symmetry.

# %% [markdown]
# ![autoencoders.png](attachment:autoencoders.png)

# %% [markdown]
# # Why Do We Apply Dimensionality Reduction to Find Outliers?

# %% [markdown]
# once the main patterns are identified, the outliers are revealed. Many distance-based techniques (e.g. KNNs) suffer the curse of dimensionality when they compute distances of every data point in the full feature space. High dimensionality has to be reduced. Interestingly, during the process of dimensionality reduction outliers are identified. We can say outlier detection is a by-product of dimension reduction.

# %% [markdown]
# # Why Autoencoders?

# %% [markdown]
# PCA uses linear algebra to transform.
#
# the autoencoder techniques can perform non-linear transformations with their non-linear activation function and multiple layers. It is more efficient to train several layers with an autoencoder, rather than training one huge transformation with PCA.
# The autoencoder techniques thus show their merits when the data problems are complex and non-linear in nature.

# %% [markdown]
# # Build the Model

# %% [markdown]
# Recall that in an autoencoder model the number of the neurons of the input and output layers corresponds to the number of variables, and the number of neurons of the hidden layers is always less than that of the outside layers.

# %% [markdown]
# ## Library

# %%
import numpy as np
import pandas as pd
from pyod.models.knn import KNN
from pyod.models.auto_encoder import AutoEncoder
from pyod.utils.data import generate_data
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from pyod.models.combination import aom, moa, average, maximization
from pyod.utils.utility import standardizer
# %matplotlib notebook

# %% [markdown]
# ## generate dataset

# %%
contamination = 0.1  # percentage of outliers
n_train = 500  # number of training points
n_test = 500  # number of testing points
n_features = 25 # Number of features

X_train, y_train, X_test, y_test = generate_data(
    n_train=n_train, n_test=n_test,
    n_features= n_features,
    contamination=contamination,random_state=1234)

X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)
# Out:
# E:\programs\python\lib\site-packages\pyod\utils\data.py:190: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.8.0. Please use behaviour="new", which makes the returned datasets in the order of X_train, X_test, y_train, y_test.
#   FutureWarning)

# %% [markdown]
# ## standardize the predictors

# %%
X_train = StandardScaler().fit_transform(X_train)
X_train = pd.DataFrame(X_train)
X_test = StandardScaler().fit_transform(X_test)
X_test = pd.DataFrame(X_test)

# %% [markdown]
# ## PCA reduce to two dimensions and plot

# %%
pca = PCA(2)
x_pca = pca.fit_transform(X_train)
x_pca = pd.DataFrame(x_pca)
x_pca.columns=['PC1','PC2']

# Plot
fig = plt.subplots( figsize=(5, 5))
plt.scatter(X_train[0], X_train[1], c=y_train, alpha=0.8)
plt.title('Scatter plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="499.15">

# %% [markdown]
# ## Model specification

# %% [markdown]
# build three plain-vanilla models with different number of layers:
#
# Model 1: [25, 2, 2, 25]. The input layer and the output layer has 25 neurons each. There are two hidden layers, each has two neurons.
#
# Model 2: [25, 10, 2, 10, 25]. Besides the input layer and output layers, there are three hidden layers with 10, 2, and 10 neurons respectively.
#
# Model 3: [25, 15, 10, 2, 10, 15, 25]. There are five hidden layers with 15, 10, 2, 10, 15 neurons respectively.

# %% [markdown]
# ## Model 1

# %%
clf1 = AutoEncoder(hidden_neurons =[25, 2, 2, 25])
clf1.fit(X_train)

#Determine the Cut Point
# define an outlier? An outlier is a point that is distant from other points, 
# so the outlier score is defined by distance. 
# The PyOD function .decision_function() calculates the distance or 
# the anomaly score for each data point.

# Get the outlier scores for the train data
y_train_scores = clf1.decision_scores_  

# Predict the anomaly scores
y_test_scores = clf1.decision_function(X_test)  # outlier scores
y_test_scores = pd.Series(y_test_scores)

# Plot it!
fig = plt.subplots( figsize=(5, 5))
plt.hist(y_test_scores, bins='auto')  
plt.title("Histogram for Model Clf1 Anomaly Scores")
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 25)                650
# _________________________________________________________________
# dropout (Dropout)            (None, 25)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                650
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                650
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 52
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 25)                75
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 25)                650
# =================================================================
# Total params: 2,733
# Trainable params: 2,733
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 450 samples, validate on 50 samples
# Epoch 1/100
# 450/450 [==============================] - 5s 12ms/sample - loss: 5.1432 - val_loss: 4.1374
# Epoch 2/100
# 450/450 [==============================] - 0s 184us/sample - loss: 3.8690 - val_loss: 3.4747
# Epoch 3/100
# 450/450 [==============================] - 0s 187us/sample - loss: 3.2612 - val_loss: 3.0944
# Epoch 4/100
# 450/450 [==============================] - 0s 189us/sample - loss: 2.8626 - val_loss: 2.8490
# Epoch 5/100
# 450/450 [==============================] - 0s 193us/sample - loss: 2.5911 - val_loss: 2.6416
# Epoch 6/100
# 450/450 [==============================] - 0s 216us/sample - loss: 2.4048 - val_loss: 2.4956
# Epoch 7/100
# 450/450 [==============================] - 0s 182us/sample - loss: 2.2416 - val_loss: 2.3707
# Epoch 8/100
# 450/450 [==============================] - 0s 209us/sample - loss: 2.1187 - val_loss: 2.2417
# Epoch 9/100
# 450/450 [==============================] - 0s 222us/sample - loss: 1.9909 - val_loss: 2.1180
# Epoch 10/100
# 450/450 [==============================] - 0s 182us/sample - loss: 1.8725 - val_loss: 2.0188
# Epoch 11/100
# 450/450 [==============================] - 0s 169us/sample - loss: 1.7857 - val_loss: 1.9368
# Epoch 12/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.7041 - val_loss: 1.8682
# Epoch 13/100
# 450/450 [==============================] - 0s 180us/sample - loss: 1.6516 - val_loss: 1.8091
# Epoch 14/100
# 450/450 [==============================] - 0s 182us/sample - loss: 1.5933 - val_loss: 1.7613
# Epoch 15/100
# 450/450 [==============================] - 0s 176us/sample - loss: 1.5489 - val_loss: 1.7172
# Epoch 16/100
# 450/450 [==============================] - 0s 173us/sample - loss: 1.5211 - val_loss: 1.6801
# Epoch 17/100
# 450/450 [==============================] - 0s 189us/sample - loss: 1.4816 - val_loss: 1.6472
# Epoch 18/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.4449 - val_loss: 1.6203
# Epoch 19/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.4330 - val_loss: 1.5969
# Epoch 20/100
# 450/450 [==============================] - 0s 176us/sample - loss: 1.4128 - val_loss: 1.5740
# Epoch 21/100
# 450/450 [==============================] - 0s 180us/sample - loss: 1.3914 - val_loss: 1.5534
# Epoch 22/100
# 450/450 [==============================] - 0s 173us/sample - loss: 1.3729 - val_loss: 1.5326
# Epoch 23/100
# 450/450 [==============================] - 0s 182us/sample - loss: 1.3560 - val_loss: 1.5128
# Epoch 24/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.3426 - val_loss: 1.4949
# Epoch 25/100
# 450/450 [==============================] - 0s 191us/sample - loss: 1.3232 - val_loss: 1.4804
# Epoch 26/100
# 450/450 [==============================] - 0s 176us/sample - loss: 1.3148 - val_loss: 1.4669
# Epoch 27/100
# 450/450 [==============================] - 0s 182us/sample - loss: 1.3014 - val_loss: 1.4547
# Epoch 28/100
# 450/450 [==============================] - 0s 180us/sample - loss: 1.2860 - val_loss: 1.4428
# Epoch 29/100
# 450/450 [==============================] - 0s 193us/sample - loss: 1.2759 - val_loss: 1.4305
# Epoch 30/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.2682 - val_loss: 1.4180
# Epoch 31/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.2567 - val_loss: 1.4071
# Epoch 32/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.2461 - val_loss: 1.3985
# Epoch 33/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.2424 - val_loss: 1.3883
# Epoch 34/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.2342 - val_loss: 1.3786
# Epoch 35/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.2262 - val_loss: 1.3686
# Epoch 36/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.2183 - val_loss: 1.3603
# Epoch 37/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.2158 - val_loss: 1.3532
# Epoch 38/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.2020 - val_loss: 1.3471
# Epoch 39/100
# 450/450 [==============================] - 0s 189us/sample - loss: 1.1968 - val_loss: 1.3402
# Epoch 40/100
# 450/450 [==============================] - 0s 182us/sample - loss: 1.1910 - val_loss: 1.3336
# Epoch 41/100
# 450/450 [==============================] - 0s 171us/sample - loss: 1.1878 - val_loss: 1.3276
# Epoch 42/100
# 450/450 [==============================] - 0s 193us/sample - loss: 1.1824 - val_loss: 1.3216
# Epoch 43/100
# 450/450 [==============================] - 0s 173us/sample - loss: 1.1750 - val_loss: 1.3154
# Epoch 44/100
# 450/450 [==============================] - 0s 236us/sample - loss: 1.1753 - val_loss: 1.3064
# Epoch 45/100
# 450/450 [==============================] - 0s 249us/sample - loss: 1.1697 - val_loss: 1.2992
# Epoch 46/100
# 450/450 [==============================] - 0s 302us/sample - loss: 1.1649 - val_loss: 1.2936
# Epoch 47/100
# 450/450 [==============================] - 0s 204us/sample - loss: 1.1624 - val_loss: 1.2887
# Epoch 48/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.1557 - val_loss: 1.2848
# Epoch 49/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.1505 - val_loss: 1.2811
# Epoch 50/100
# 450/450 [==============================] - 0s 176us/sample - loss: 1.1492 - val_loss: 1.2772
# Epoch 51/100
# 450/450 [==============================] - 0s 191us/sample - loss: 1.1457 - val_loss: 1.2730
# Epoch 52/100
# 450/450 [==============================] - 0s 249us/sample - loss: 1.1420 - val_loss: 1.2658
# Epoch 53/100
# 450/450 [==============================] - 0s 222us/sample - loss: 1.1393 - val_loss: 1.2617
# Epoch 54/100
# 450/450 [==============================] - 0s 227us/sample - loss: 1.1303 - val_loss: 1.2567
# Epoch 55/100
# 450/450 [==============================] - 0s 213us/sample - loss: 1.1369 - val_loss: 1.2532
# Epoch 56/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.1292 - val_loss: 1.2507
# Epoch 57/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.1259 - val_loss: 1.2478
# Epoch 58/100
# 450/450 [==============================] - 0s 224us/sample - loss: 1.1257 - val_loss: 1.2443
# Epoch 59/100
# 450/450 [==============================] - 0s 212us/sample - loss: 1.1195 - val_loss: 1.2429
# Epoch 60/100
# 450/450 [==============================] - 0s 202us/sample - loss: 1.1175 - val_loss: 1.2392
# Epoch 61/100
# 450/450 [==============================] - 0s 193us/sample - loss: 1.1195 - val_loss: 1.2362
# Epoch 62/100
# 450/450 [==============================] - 0s 224us/sample - loss: 1.1163 - val_loss: 1.2323
# Epoch 63/100
# 450/450 [==============================] - 0s 180us/sample - loss: 1.1088 - val_loss: 1.2302
# Epoch 64/100
# 450/450 [==============================] - 0s 169us/sample - loss: 1.1071 - val_loss: 1.2300
# Epoch 65/100
# 450/450 [==============================] - 0s 169us/sample - loss: 1.1048 - val_loss: 1.2269
# Epoch 66/100
# 450/450 [==============================] - 0s 173us/sample - loss: 1.1040 - val_loss: 1.2237
# Epoch 67/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.1051 - val_loss: 1.2217
# Epoch 68/100
# 450/450 [==============================] - 0s 176us/sample - loss: 1.1033 - val_loss: 1.2184
# Epoch 69/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.0969 - val_loss: 1.2148
# Epoch 70/100
# 450/450 [==============================] - 0s 182us/sample - loss: 1.1002 - val_loss: 1.2130
# Epoch 71/100
# 450/450 [==============================] - 0s 182us/sample - loss: 1.0919 - val_loss: 1.2121
# Epoch 72/100
# 450/450 [==============================] - 0s 167us/sample - loss: 1.0944 - val_loss: 1.2110
# Epoch 73/100
# 450/450 [==============================] - 0s 191us/sample - loss: 1.0933 - val_loss: 1.2069
# Epoch 74/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.0902 - val_loss: 1.2043
# Epoch 75/100
# 450/450 [==============================] - 0s 211us/sample - loss: 1.0894 - val_loss: 1.2077
# Epoch 76/100
# 450/450 [==============================] - 0s 209us/sample - loss: 1.0860 - val_loss: 1.2046
# Epoch 77/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.0842 - val_loss: 1.2000
# Epoch 78/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.0862 - val_loss: 1.1980
# Epoch 79/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.0859 - val_loss: 1.1964
# Epoch 80/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.0865 - val_loss: 1.1928
# Epoch 81/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.0812 - val_loss: 1.1912
# Epoch 82/100
# 450/450 [==============================] - 0s 176us/sample - loss: 1.0775 - val_loss: 1.1925
# Epoch 83/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.0751 - val_loss: 1.1908
# Epoch 84/100
# 450/450 [==============================] - 0s 204us/sample - loss: 1.0787 - val_loss: 1.1905
# Epoch 85/100
# 450/450 [==============================] - 0s 231us/sample - loss: 1.0773 - val_loss: 1.1908
# Epoch 86/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.0802 - val_loss: 1.1861
# Epoch 87/100
# 450/450 [==============================] - 0s 173us/sample - loss: 1.0755 - val_loss: 1.1829
# Epoch 88/100
# 450/450 [==============================] - 0s 173us/sample - loss: 1.0767 - val_loss: 1.1804
# Epoch 89/100
# 450/450 [==============================] - 0s 180us/sample - loss: 1.0711 - val_loss: 1.1785
# Epoch 90/100
# 450/450 [==============================] - 0s 171us/sample - loss: 1.0710 - val_loss: 1.1767
# Epoch 91/100
# 450/450 [==============================] - 0s 180us/sample - loss: 1.0713 - val_loss: 1.1741
# Epoch 92/100
# 450/450 [==============================] - 0s 191us/sample - loss: 1.0677 - val_loss: 1.1766
# Epoch 93/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.0705 - val_loss: 1.1764
# Epoch 94/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.0646 - val_loss: 1.1730
# Epoch 95/100
# 450/450 [==============================] - 0s 176us/sample - loss: 1.0686 - val_loss: 1.1702
# Epoch 96/100
# 450/450 [==============================] - 0s 173us/sample - loss: 1.0630 - val_loss: 1.1691
# Epoch 97/100
# 450/450 [==============================] - 0s 189us/sample - loss: 1.0628 - val_loss: 1.1692
# Epoch 98/100
# 450/450 [==============================] - 0s 171us/sample - loss: 1.0664 - val_loss: 1.1670
# Epoch 99/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.0667 - val_loss: 1.1635
# Epoch 100/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.0621 - val_loss: 1.1597
# <img src="data:image/png;base64,..." width="499.15">

# %% [markdown]
# If we use a histogram to count the frequency by the anomaly score, we will see the high scores corresponds to low frequency — the evidence of outliers. We choose 4.0 to be the cut point and those >=4.0 to be outliers.`

# %% [markdown]
# ## the Summary Statistics by Cluster

# %% [markdown]
# Let’s assign those observations with less than 4.0 anomaly scores to Cluster 0, and to Cluster 1 for those above 4.0 (see how I use np.where() in the code). I calculate the summary statistics by cluster using .groupby() . This model has identified 50 outliers.

# %%
df_test = X_test.copy()
df_test['score'] = y_test_scores
df_test['cluster'] = np.where(df_test['score']<4, 0, 1)
df_test['cluster'].value_counts()

df_test.groupby('cluster').mean()
# Out:
#                 0         1         2         3         4         5         6  \
# cluster
# 0        0.248812  0.235591  0.254013  0.239429  0.239101  0.255499  0.257207
# 1       -2.239305 -2.120321 -2.286113 -2.154863 -2.151912 -2.299489 -2.314860
#
#                7         8         9  ...        16        17        18  \
# cluster                               ...
# 0        0.24438  0.248004  0.251948  ...  0.247737  0.251469  0.259140
# 1       -2.19942 -2.232040 -2.267535  ... -2.229637 -2.263223 -2.332263
#
#                19        20        21        22        23        24      score
# cluster
# 0        0.249625  0.235669  0.244511  0.237602  0.246901  0.249373   2.697083
# 1       -2.246622 -2.121021 -2.200595 -2.138417 -2.222110 -2.244355  13.408308
#
# [2 rows x 26 columns]

# %% [markdown]
# The following output shows the mean variable values in each cluster. The values of Cluster ‘1’ (the abnormal cluster) is quite different from those of Cluster ‘0’ (the normal cluster). The “score” values show the average distance of those observations to others. A high “score” means that observation is far away from the norm.

# %% [markdown]
# ## Model 2

# %%
clf2 = AutoEncoder(hidden_neurons =[25, 10,2, 10, 25])
clf2.fit(X_train)

# Predict the anomaly scores
y_test_scores = clf2.decision_function(X_test)  
y_test_scores = pd.Series(y_test_scores)

# Plot the histogram
fig = plt.subplots( figsize=(5, 5))
plt.hist(y_test_scores, bins='auto')  
plt.title("Histogram for Model Clf2 Anomaly Scores")
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 25)                650
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 25)                650
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 25)                650
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                260
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 22
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2)                 0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                30
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 25)                275
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 25)                650
# =================================================================
# Total params: 3,187
# Trainable params: 3,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 450 samples, validate on 50 samples
# Epoch 1/100
# 450/450 [==============================] - 1s 2ms/sample - loss: 4.2588 - val_loss: 3.8315
# Epoch 2/100
# 450/450 [==============================] - 0s 202us/sample - loss: 3.4008 - val_loss: 3.3187
# Epoch 3/100
# 450/450 [==============================] - 0s 203us/sample - loss: 2.9377 - val_loss: 3.0010
# Epoch 4/100
# 450/450 [==============================] - 0s 184us/sample - loss: 2.6407 - val_loss: 2.7859
# Epoch 5/100
# 450/450 [==============================] - 0s 191us/sample - loss: 2.4523 - val_loss: 2.6206
# Epoch 6/100
# 450/450 [==============================] - 0s 184us/sample - loss: 2.3041 - val_loss: 2.4728
# Epoch 7/100
# 450/450 [==============================] - 0s 196us/sample - loss: 2.1514 - val_loss: 2.3309
# Epoch 8/100
# 450/450 [==============================] - 0s 191us/sample - loss: 2.0359 - val_loss: 2.1945
# Epoch 9/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.9096 - val_loss: 2.0774
# Epoch 10/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.8106 - val_loss: 1.9905
# Epoch 11/100
# 450/450 [==============================] - 0s 193us/sample - loss: 1.7310 - val_loss: 1.9169
# Epoch 12/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.6747 - val_loss: 1.8597
# Epoch 13/100
# 450/450 [==============================] - 0s 202us/sample - loss: 1.6243 - val_loss: 1.8121
# Epoch 14/100
# 450/450 [==============================] - 0s 220us/sample - loss: 1.5830 - val_loss: 1.7643
# Epoch 15/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.5551 - val_loss: 1.7276
# Epoch 16/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.5111 - val_loss: 1.6949
# Epoch 17/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.4808 - val_loss: 1.6617
# Epoch 18/100
# 450/450 [==============================] - 0s 238us/sample - loss: 1.4551 - val_loss: 1.6349
# Epoch 19/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.4296 - val_loss: 1.6129
# Epoch 20/100
# 450/450 [==============================] - 0s 193us/sample - loss: 1.4054 - val_loss: 1.5901
# Epoch 21/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.3856 - val_loss: 1.5713
# Epoch 22/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.3641 - val_loss: 1.5528
# Epoch 23/100
# 450/450 [==============================] - 0s 227us/sample - loss: 1.3474 - val_loss: 1.5368
# Epoch 24/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.3355 - val_loss: 1.5213
# Epoch 25/100
# 450/450 [==============================] - 0s 204us/sample - loss: 1.3185 - val_loss: 1.5061
# Epoch 26/100
# 450/450 [==============================] - 0s 200us/sample - loss: 1.3098 - val_loss: 1.4922
# Epoch 27/100
# 450/450 [==============================] - 0s 189us/sample - loss: 1.2888 - val_loss: 1.4786
# Epoch 28/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.2801 - val_loss: 1.4660
# Epoch 29/100
# 450/450 [==============================] - 0s 189us/sample - loss: 1.2740 - val_loss: 1.4545
# Epoch 30/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.2619 - val_loss: 1.4438
# Epoch 31/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.2487 - val_loss: 1.4335
# Epoch 32/100
# 450/450 [==============================] - 0s 180us/sample - loss: 1.2414 - val_loss: 1.4243
# Epoch 33/100
# 450/450 [==============================] - 0s 218us/sample - loss: 1.2367 - val_loss: 1.4146
# Epoch 34/100
# 450/450 [==============================] - 0s 209us/sample - loss: 1.2223 - val_loss: 1.4054
# Epoch 35/100
# 450/450 [==============================] - 0s 193us/sample - loss: 1.2155 - val_loss: 1.3979
# Epoch 36/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.2059 - val_loss: 1.3906
# Epoch 37/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.1993 - val_loss: 1.3830
# Epoch 38/100
# 450/450 [==============================] - 0s 222us/sample - loss: 1.1936 - val_loss: 1.3745
# Epoch 39/100
# 450/450 [==============================] - 0s 209us/sample - loss: 1.1921 - val_loss: 1.3677
# Epoch 40/100
# 450/450 [==============================] - 0s 202us/sample - loss: 1.1789 - val_loss: 1.3619
# Epoch 41/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.1761 - val_loss: 1.3559
# Epoch 42/100
# 450/450 [==============================] - 0s 202us/sample - loss: 1.1735 - val_loss: 1.3503
# Epoch 43/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.1676 - val_loss: 1.3451
# Epoch 44/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.1595 - val_loss: 1.3399
# Epoch 45/100
# 450/450 [==============================] - 0s 176us/sample - loss: 1.1581 - val_loss: 1.3351
# Epoch 46/100
# 450/450 [==============================] - 0s 202us/sample - loss: 1.1546 - val_loss: 1.3295
# Epoch 47/100
# 450/450 [==============================] - 0s 182us/sample - loss: 1.1489 - val_loss: 1.3251
# Epoch 48/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.1477 - val_loss: 1.3209
# Epoch 49/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.1394 - val_loss: 1.3166
# Epoch 50/100
# 450/450 [==============================] - 0s 180us/sample - loss: 1.1374 - val_loss: 1.3114
# Epoch 51/100
# 450/450 [==============================] - 0s 176us/sample - loss: 1.1355 - val_loss: 1.3080
# Epoch 52/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.1320 - val_loss: 1.3049
# Epoch 53/100
# 450/450 [==============================] - 0s 176us/sample - loss: 1.1252 - val_loss: 1.3017
# Epoch 54/100
# 450/450 [==============================] - 0s 173us/sample - loss: 1.1276 - val_loss: 1.2986
# Epoch 55/100
# 450/450 [==============================] - 0s 176us/sample - loss: 1.1241 - val_loss: 1.2955
# Epoch 56/100
# 450/450 [==============================] - 0s 173us/sample - loss: 1.1160 - val_loss: 1.2926
# Epoch 57/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.1152 - val_loss: 1.2895
# Epoch 58/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.1164 - val_loss: 1.2850
# Epoch 59/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.1104 - val_loss: 1.2823
# Epoch 60/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.1063 - val_loss: 1.2801
# Epoch 61/100
# 450/450 [==============================] - 0s 182us/sample - loss: 1.1073 - val_loss: 1.2780
# Epoch 62/100
# 450/450 [==============================] - 0s 189us/sample - loss: 1.1032 - val_loss: 1.2755
# Epoch 63/100
# 450/450 [==============================] - 0s 220us/sample - loss: 1.1047 - val_loss: 1.2734
# Epoch 64/100
# 450/450 [==============================] - 0s 200us/sample - loss: 1.1010 - val_loss: 1.2714
# Epoch 65/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.0960 - val_loss: 1.2691
# Epoch 66/100
# 450/450 [==============================] - 0s 193us/sample - loss: 1.0958 - val_loss: 1.2670
# Epoch 67/100
# 450/450 [==============================] - 0s 204us/sample - loss: 1.0927 - val_loss: 1.2648
# Epoch 68/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.0895 - val_loss: 1.2621
# Epoch 69/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.0937 - val_loss: 1.2602
# Epoch 70/100
# 450/450 [==============================] - 0s 204us/sample - loss: 1.0895 - val_loss: 1.2586
# Epoch 71/100
# 450/450 [==============================] - 0s 209us/sample - loss: 1.0861 - val_loss: 1.2569
# Epoch 72/100
# 450/450 [==============================] - 0s 202us/sample - loss: 1.0850 - val_loss: 1.2554
# Epoch 73/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.0831 - val_loss: 1.2537
# Epoch 74/100
# 450/450 [==============================] - 0s 202us/sample - loss: 1.0819 - val_loss: 1.2521
# Epoch 75/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.0825 - val_loss: 1.2505
# Epoch 76/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.0800 - val_loss: 1.2489
# Epoch 77/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.0810 - val_loss: 1.2476
# Epoch 78/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.0810 - val_loss: 1.2461
# Epoch 79/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.0741 - val_loss: 1.2447
# Epoch 80/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.0725 - val_loss: 1.2434
# Epoch 81/100
# 450/450 [==============================] - 0s 209us/sample - loss: 1.0723 - val_loss: 1.2421
# Epoch 82/100
# 450/450 [==============================] - 0s 218us/sample - loss: 1.0720 - val_loss: 1.2406
# Epoch 83/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.0708 - val_loss: 1.2394
# Epoch 84/100
# 450/450 [==============================] - 0s 204us/sample - loss: 1.0706 - val_loss: 1.2383
# Epoch 85/100
# 450/450 [==============================] - 0s 204us/sample - loss: 1.0690 - val_loss: 1.2371
# Epoch 86/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.0688 - val_loss: 1.2360
# Epoch 87/100
# 450/450 [==============================] - 0s 189us/sample - loss: 1.0659 - val_loss: 1.2349
# Epoch 88/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.0664 - val_loss: 1.2335
# Epoch 89/100
# 450/450 [==============================] - 0s 200us/sample - loss: 1.0598 - val_loss: 1.2325
# Epoch 90/100
# 450/450 [==============================] - 0s 182us/sample - loss: 1.0632 - val_loss: 1.2316
# Epoch 91/100
# 450/450 [==============================] - 0s 209us/sample - loss: 1.0646 - val_loss: 1.2307
# Epoch 92/100
# 450/450 [==============================] - 0s 200us/sample - loss: 1.0600 - val_loss: 1.2294
# Epoch 93/100
# 450/450 [==============================] - 0s 193us/sample - loss: 1.0645 - val_loss: 1.2282
# Epoch 94/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.0604 - val_loss: 1.2272
# Epoch 95/100
# 450/450 [==============================] - 0s 211us/sample - loss: 1.0587 - val_loss: 1.2263
# Epoch 96/100
# 450/450 [==============================] - 0s 200us/sample - loss: 1.0611 - val_loss: 1.2255
# Epoch 97/100
# 450/450 [==============================] - 0s 191us/sample - loss: 1.0570 - val_loss: 1.2247
# Epoch 98/100
# 450/450 [==============================] - 0s 187us/sample - loss: 1.0567 - val_loss: 1.2238
# Epoch 99/100
# 450/450 [==============================] - 0s 178us/sample - loss: 1.0521 - val_loss: 1.2229
# Epoch 100/100
# 450/450 [==============================] - 0s 171us/sample - loss: 1.0558 - val_loss: 1.2221
# <img src="data:image/png;base64,..." width="499.15">

# %% [markdown]
# ## the Summary Statistics by Cluster

# %%
df_test = X_test.copy()
df_test['score'] = y_test_scores
df_test['cluster'] = np.where(df_test['score']<4, 0, 1)
df_test['cluster'].value_counts()
df_test.groupby('cluster').mean()
# Out:
#                 0         1         2         3         4         5         6  \
# cluster
# 0        0.248812  0.235591  0.254013  0.239429  0.239101  0.255499  0.257207
# 1       -2.239305 -2.120321 -2.286113 -2.154863 -2.151912 -2.299489 -2.314860
#
#                7         8         9  ...        16        17        18  \
# cluster                               ...
# 0        0.24438  0.248004  0.251948  ...  0.247737  0.251469  0.259140
# 1       -2.19942 -2.232040 -2.267535  ... -2.229637 -2.263223 -2.332263
#
#                19        20        21        22        23        24      score
# cluster
# 0        0.249625  0.235669  0.244511  0.237602  0.246901  0.249373   2.719728
# 1       -2.246622 -2.121021 -2.200595 -2.138417 -2.222110 -2.244355  13.486114
#
# [2 rows x 26 columns]

# %% [markdown]
# The summary statistic of Cluster ‘1’ (the abnormal cluster) is different from those of Cluster ‘0’ (the normal cluster). The observations in Cluster 1 are outliers.

# %% [markdown]
# ## Model 3

# %%
# Step 1: Build the model
clf3 = AutoEncoder(hidden_neurons =[25, 15, 10, 2, 10,15, 25])
clf3.fit(X_train)

# Predict the anomaly scores
y_test_scores = clf3.decision_function(X_test)  
y_test_scores = pd.Series(y_test_scores)

# Step 2: Determine the cut point
fig = plt.subplots( figsize=(5, 5))
plt.hist(y_test_scores, bins='auto')  
plt.title("Histogram with Model Clf3 Anomaly Scores")
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 25)                650
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 25)                650
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 25)                650
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 15)                390
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 15)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                160
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 22
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 2)                 0
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                30
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 15)                165
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 15)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 25)                400
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 25)                650
# =================================================================
# Total params: 3,767
# Trainable params: 3,767
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 450 samples, validate on 50 samples
# Epoch 1/100
# 450/450 [==============================] - 1s 3ms/sample - loss: 3.8517 - val_loss: 2.2274
# Epoch 2/100
# 450/450 [==============================] - 0s 256us/sample - loss: 3.0836 - val_loss: 2.0065
# Epoch 3/100
# 450/450 [==============================] - 0s 213us/sample - loss: 2.7658 - val_loss: 1.8581
# Epoch 4/100
# 450/450 [==============================] - 0s 222us/sample - loss: 2.4928 - val_loss: 1.7326
# Epoch 5/100
# 450/450 [==============================] - 0s 247us/sample - loss: 2.3278 - val_loss: 1.6130
# Epoch 6/100
# 450/450 [==============================] - 0s 218us/sample - loss: 2.1627 - val_loss: 1.5048
# Epoch 7/100
# 450/450 [==============================] - 0s 224us/sample - loss: 2.0459 - val_loss: 1.4201
# Epoch 8/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.9394 - val_loss: 1.3528
# Epoch 9/100
# 450/450 [==============================] - 0s 211us/sample - loss: 1.8533 - val_loss: 1.2998
# Epoch 10/100
# 450/450 [==============================] - 0s 204us/sample - loss: 1.7884 - val_loss: 1.2518
# Epoch 11/100
# 450/450 [==============================] - 0s 202us/sample - loss: 1.7212 - val_loss: 1.2130
# Epoch 12/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.6780 - val_loss: 1.1784
# Epoch 13/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.6302 - val_loss: 1.1518
# Epoch 14/100
# 450/450 [==============================] - 0s 213us/sample - loss: 1.5994 - val_loss: 1.1223
# Epoch 15/100
# 450/450 [==============================] - 0s 258us/sample - loss: 1.5672 - val_loss: 1.1025
# Epoch 16/100
# 450/450 [==============================] - 0s 231us/sample - loss: 1.5372 - val_loss: 1.0779
# Epoch 17/100
# 450/450 [==============================] - 0s 236us/sample - loss: 1.5050 - val_loss: 1.0559
# Epoch 18/100
# 450/450 [==============================] - 0s 249us/sample - loss: 1.4828 - val_loss: 1.0364
# Epoch 19/100
# 450/450 [==============================] - 0s 262us/sample - loss: 1.4636 - val_loss: 1.0198
# Epoch 20/100
# 450/450 [==============================] - 0s 240us/sample - loss: 1.4424 - val_loss: 1.0040
# Epoch 21/100
# 450/450 [==============================] - 0s 238us/sample - loss: 1.4261 - val_loss: 0.9881
# Epoch 22/100
# 450/450 [==============================] - 0s 218us/sample - loss: 1.4070 - val_loss: 0.9736
# Epoch 23/100
# 450/450 [==============================] - 0s 224us/sample - loss: 1.3873 - val_loss: 0.9607
# Epoch 24/100
# 450/450 [==============================] - 0s 227us/sample - loss: 1.3748 - val_loss: 0.9483
# Epoch 25/100
# 450/450 [==============================] - 0s 240us/sample - loss: 1.3587 - val_loss: 0.9383
# Epoch 26/100
# 450/450 [==============================] - 0s 222us/sample - loss: 1.3446 - val_loss: 0.9302
# Epoch 27/100
# 450/450 [==============================] - 0s 229us/sample - loss: 1.3317 - val_loss: 0.9180
# Epoch 28/100
# 450/450 [==============================] - 0s 244us/sample - loss: 1.3203 - val_loss: 0.9073
# Epoch 29/100
# 450/450 [==============================] - 0s 227us/sample - loss: 1.3103 - val_loss: 0.8973
# Epoch 30/100
# 450/450 [==============================] - 0s 222us/sample - loss: 1.3000 - val_loss: 0.8919
# Epoch 31/100
# 450/450 [==============================] - 0s 220us/sample - loss: 1.2891 - val_loss: 0.8812
# Epoch 32/100
# 450/450 [==============================] - 0s 213us/sample - loss: 1.2853 - val_loss: 0.8729
# Epoch 33/100
# 450/450 [==============================] - 0s 218us/sample - loss: 1.2713 - val_loss: 0.8654
# Epoch 34/100
# 450/450 [==============================] - 0s 233us/sample - loss: 1.2682 - val_loss: 0.8597
# Epoch 35/100
# 450/450 [==============================] - 0s 220us/sample - loss: 1.2596 - val_loss: 0.8609
# Epoch 36/100
# 450/450 [==============================] - 0s 213us/sample - loss: 1.2516 - val_loss: 0.8522
# Epoch 37/100
# 450/450 [==============================] - 0s 233us/sample - loss: 1.2472 - val_loss: 0.8420
# Epoch 38/100
# 450/450 [==============================] - 0s 220us/sample - loss: 1.2390 - val_loss: 0.8374
# Epoch 39/100
# 450/450 [==============================] - 0s 229us/sample - loss: 1.2306 - val_loss: 0.8314
# Epoch 40/100
# 450/450 [==============================] - 0s 253us/sample - loss: 1.2242 - val_loss: 0.8258
# Epoch 41/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.2229 - val_loss: 0.8207
# Epoch 42/100
# 450/450 [==============================] - 0s 218us/sample - loss: 1.2163 - val_loss: 0.8173
# Epoch 43/100
# 450/450 [==============================] - 0s 200us/sample - loss: 1.2089 - val_loss: 0.8142
# Epoch 44/100
# 450/450 [==============================] - 0s 211us/sample - loss: 1.2075 - val_loss: 0.8088
# Epoch 45/100
# 450/450 [==============================] - 0s 227us/sample - loss: 1.2031 - val_loss: 0.8053
# Epoch 46/100
# 450/450 [==============================] - 0s 262us/sample - loss: 1.1963 - val_loss: 0.8010
# Epoch 47/100
# 450/450 [==============================] - 0s 213us/sample - loss: 1.1950 - val_loss: 0.7964
# Epoch 48/100
# 450/450 [==============================] - 0s 213us/sample - loss: 1.1894 - val_loss: 0.7940
# Epoch 49/100
# 450/450 [==============================] - 0s 204us/sample - loss: 1.1869 - val_loss: 0.7909
# Epoch 50/100
# 450/450 [==============================] - 0s 218us/sample - loss: 1.1871 - val_loss: 0.7886
# Epoch 51/100
# 450/450 [==============================] - 0s 209us/sample - loss: 1.1840 - val_loss: 0.7909
# Epoch 52/100
# 450/450 [==============================] - 0s 218us/sample - loss: 1.1818 - val_loss: 0.7847
# Epoch 53/100
# 450/450 [==============================] - 0s 227us/sample - loss: 1.1762 - val_loss: 0.7797
# Epoch 54/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.1747 - val_loss: 0.7769
# Epoch 55/100
# 450/450 [==============================] - 0s 218us/sample - loss: 1.1703 - val_loss: 0.7745
# Epoch 56/100
# 450/450 [==============================] - 0s 220us/sample - loss: 1.1648 - val_loss: 0.7715
# Epoch 57/100
# 450/450 [==============================] - 0s 211us/sample - loss: 1.1652 - val_loss: 0.7717
# Epoch 58/100
# 450/450 [==============================] - 0s 222us/sample - loss: 1.1619 - val_loss: 0.7682
# Epoch 59/100
# 450/450 [==============================] - 0s 256us/sample - loss: 1.1639 - val_loss: 0.7652
# Epoch 60/100
# 450/450 [==============================] - 0s 233us/sample - loss: 1.1567 - val_loss: 0.7639
# Epoch 61/100
# 450/450 [==============================] - 0s 227us/sample - loss: 1.1541 - val_loss: 0.7618
# Epoch 62/100
# 450/450 [==============================] - 0s 220us/sample - loss: 1.1553 - val_loss: 0.7604
# Epoch 63/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.1527 - val_loss: 0.7587
# Epoch 64/100
# 450/450 [==============================] - 0s 229us/sample - loss: 1.1487 - val_loss: 0.7564
# Epoch 65/100
# 450/450 [==============================] - 0s 236us/sample - loss: 1.1489 - val_loss: 0.7548
# Epoch 66/100
# 450/450 [==============================] - 0s 240us/sample - loss: 1.1443 - val_loss: 0.7527
# Epoch 67/100
# 450/450 [==============================] - 0s 224us/sample - loss: 1.1418 - val_loss: 0.7515
# Epoch 68/100
# 450/450 [==============================] - 0s 244us/sample - loss: 1.1447 - val_loss: 0.7500
# Epoch 69/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.1432 - val_loss: 0.7492
# Epoch 70/100
# 450/450 [==============================] - 0s 213us/sample - loss: 1.1421 - val_loss: 0.7477
# Epoch 71/100
# 450/450 [==============================] - 0s 224us/sample - loss: 1.1362 - val_loss: 0.7464
# Epoch 72/100
# 450/450 [==============================] - 0s 227us/sample - loss: 1.1359 - val_loss: 0.7448
# Epoch 73/100
# 450/450 [==============================] - 0s 220us/sample - loss: 1.1337 - val_loss: 0.7449
# Epoch 74/100
# 450/450 [==============================] - 0s 224us/sample - loss: 1.1310 - val_loss: 0.7438
# Epoch 75/100
# 450/450 [==============================] - 0s 251us/sample - loss: 1.1332 - val_loss: 0.7424
# Epoch 76/100
# 450/450 [==============================] - 0s 224us/sample - loss: 1.1319 - val_loss: 0.7412
# Epoch 77/100
# 450/450 [==============================] - 0s 236us/sample - loss: 1.1246 - val_loss: 0.7397
# Epoch 78/100
# 450/450 [==============================] - 0s 227us/sample - loss: 1.1257 - val_loss: 0.7394
# Epoch 79/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.1258 - val_loss: 0.7383
# Epoch 80/100
# 450/450 [==============================] - 0s 260us/sample - loss: 1.1248 - val_loss: 0.7368
# Epoch 81/100
# 450/450 [==============================] - 0s 231us/sample - loss: 1.1259 - val_loss: 0.7356
# Epoch 82/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.1243 - val_loss: 0.7345
# Epoch 83/100
# 450/450 [==============================] - 0s 213us/sample - loss: 1.1227 - val_loss: 0.7350
# Epoch 84/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.1196 - val_loss: 0.7339
# Epoch 85/100
# 450/450 [==============================] - 0s 242us/sample - loss: 1.1221 - val_loss: 0.7321
# Epoch 86/100
# 450/450 [==============================] - 0s 216us/sample - loss: 1.1211 - val_loss: 0.7310
# Epoch 87/100
# 450/450 [==============================] - 0s 240us/sample - loss: 1.1208 - val_loss: 0.7305
# Epoch 88/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.1178 - val_loss: 0.7309
# Epoch 89/100
# 450/450 [==============================] - 0s 196us/sample - loss: 1.1203 - val_loss: 0.7297
# Epoch 90/100
# 450/450 [==============================] - 0s 193us/sample - loss: 1.1172 - val_loss: 0.7283
# Epoch 91/100
# 450/450 [==============================] - 0s 191us/sample - loss: 1.1170 - val_loss: 0.7273
# Epoch 92/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.1133 - val_loss: 0.7262
# Epoch 93/100
# 450/450 [==============================] - 0s 198us/sample - loss: 1.1127 - val_loss: 0.7257
# Epoch 94/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.1162 - val_loss: 0.7245
# Epoch 95/100
# 450/450 [==============================] - 0s 180us/sample - loss: 1.1110 - val_loss: 0.7257
# Epoch 96/100
# 450/450 [==============================] - 0s 182us/sample - loss: 1.1115 - val_loss: 0.7247
# Epoch 97/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.1139 - val_loss: 0.7234
# Epoch 98/100
# 450/450 [==============================] - 0s 184us/sample - loss: 1.1060 - val_loss: 0.7224
# Epoch 99/100
# 450/450 [==============================] - 0s 262us/sample - loss: 1.1102 - val_loss: 0.7215
# Epoch 100/100
# 450/450 [==============================] - 0s 207us/sample - loss: 1.1069 - val_loss: 0.7209
# <img src="data:image/png;base64,..." width="499.15">

# %% [markdown]
# ## the Summary Statistics by Cluster

# %%
df_test = X_test.copy()
df_test['score'] = y_test_scores
df_test['cluster'] = np.where(df_test['score']<4, 0, 1)
df_test['cluster'].value_counts()

# Step 3: Get the summary statistics by cluster
df_test.groupby('cluster').mean()
# Out:
#                 0         1         2         3         4         5         6  \
# cluster
# 0        0.248812  0.235591  0.254013  0.239429  0.239101  0.255499  0.257207
# 1       -2.239305 -2.120321 -2.286113 -2.154863 -2.151912 -2.299489 -2.314860
#
#                7         8         9  ...        16        17        18  \
# cluster                               ...
# 0        0.24438  0.248004  0.251948  ...  0.247737  0.251469  0.259140
# 1       -2.19942 -2.232040 -2.267535  ... -2.229637 -2.263223 -2.332263
#
#                19        20        21        22        23        24      score
# cluster
# 0        0.249625  0.235669  0.244511  0.237602  0.246901  0.249373   2.722468
# 1       -2.246622 -2.121021 -2.200595 -2.138417 -2.222110 -2.244355  13.478232
#
# [2 rows x 26 columns]

# %% [markdown]
# # Aggregate to Achieve Model Stability

# %% [markdown]
# Although unsupervised techniques are powerful in detecting outliers, they are prone to overfitting and unstable results. The solution is to train multiple models then aggregate the scores.

# %% [markdown]
# There are four methods to aggregate the outcome as below.
#
#    Average: average scores of all detectors.
#    Maximum of Maximum (MOM)
#    Average of Maximum (AOM)
#    Maximum of Average (MOA)

# %%
# Put all the predictions in a data frame
train_scores = pd.DataFrame({'clf1': clf1.decision_scores_,
                             'clf2': clf2.decision_scores_,
                             'clf3': clf3.decision_scores_
                            })

test_scores  = pd.DataFrame({'clf1': clf1.decision_function(X_test),
                             'clf2': clf2.decision_function(X_test),
                             'clf3': clf3.decision_function(X_test) 
                            })

# %%
# Although we did standardization before, it was for the variables.
# Now we do the standardization for the decision scores
train_scores_norm, test_scores_norm = standardizer(train_scores,test_scores)

# %% [markdown]
# ## Average Method

# %% [markdown]
# The average() function computes the average of the outlier scores from multiple models

# %%
# Combination by average
y_by_average = average(test_scores_norm)
             
fig = plt.subplots( figsize=(5, 5))
plt.hist(y_by_average, bins='auto')  # arguments are passed to np.histogram
plt.title("Combination by average")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="499.15">

# %% [markdown]
# It appears we can identify those >=0.0 as the outliers.

# %%
df_test = pd.DataFrame(X_test)
df_test['y_by_average_score'] = y_by_average
df_test['y_by_average_cluster'] = np.where(df_test['y_by_average_score']<0, 0, 1)
df_test['y_by_average_cluster'].value_counts()
# Out:
# 0    450
# 1     50
# Name: y_by_average_cluster, dtype: int64

# %%
df_test.groupby('y_by_average_cluster').mean()
# Out:
#                              0         1         2         3         4  \
# y_by_average_cluster
# 0                     0.248812  0.235591  0.254013  0.239429  0.239101
# 1                    -2.239305 -2.120321 -2.286113 -2.154863 -2.151912
#
#                              5         6        7         8         9  ...  \
# y_by_average_cluster                                                   ...
# 0                     0.255499  0.257207  0.24438  0.248004  0.251948  ...
# 1                    -2.299489 -2.314860 -2.19942 -2.232040 -2.267535  ...
#
#                             16        17        18        19        20  \
# y_by_average_cluster
# 0                     0.247737  0.251469  0.259140  0.249625  0.235669
# 1                    -2.229637 -2.263223 -2.332263 -2.246622 -2.121021
#
#                             21        22        23        24  \
# y_by_average_cluster
# 0                     0.244511  0.237602  0.246901  0.249373
# 1                    -2.200595 -2.138417 -2.222110 -2.244355
#
#                       y_by_average_score
# y_by_average_cluster
# 0                              -0.325626
# 1                               2.950611
#
# [2 rows x 26 columns]

# %% [markdown]
# ## Maximum of Maximum Method

# %% [markdown]
# Get the outlier scores from multiple models by taking the maximum.

# %%
# Combination by max
y_by_maximization = maximization(test_scores_norm)
             
import matplotlib.pyplot as plt
plt.hist(y_by_maximization, bins='auto')  # arguments are passed to np.histogram
plt.title("Combination by max")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
df_test = pd.DataFrame(X_test)
df_test['y_by_maximization_score'] = y_by_maximization
df_test['y_by_maximization_cluster'] = np.where(df_test['y_by_maximization_score']<0, 0, 1)
df_test['y_by_maximization_cluster'].value_counts()
# Out:
# 0    449
# 1     51
# Name: y_by_maximization_cluster, dtype: int64

# %%
df_test.groupby('y_by_maximization_cluster').mean()
# Out:
#                                   0         1         2         3         4  \
# y_by_maximization_cluster
# 0                          0.250641  0.234265  0.256385  0.238049  0.240912
# 1                         -2.206620 -2.062450 -2.257193 -2.095767 -2.120973
#
#                                   5         6         7         8         9  \
# y_by_maximization_cluster
# 0                          0.253722  0.259439  0.243287  0.247594  0.250054
# 1                         -2.233748 -2.284082 -2.141877 -2.179802 -2.201453
#
#                            ...        18        19        20        21  \
# y_by_maximization_cluster  ...
# 0                          ...  0.260433  0.251001  0.235403  0.245304
# 1                          ... -2.292833 -2.209791 -2.072466 -2.159639
#
#                                  22        23        24  y_by_average_score  \
# y_by_maximization_cluster
# 0                          0.236136  0.244595  0.249588           -0.326327
# 1                         -2.078922 -2.153399 -2.197357            2.892540
#
#                            y_by_average_cluster  y_by_maximization_score
# y_by_maximization_cluster
# 0                                      0.000000                -0.323563
# 1                                      0.980392                 2.910850
#
# [2 rows x 28 columns]
