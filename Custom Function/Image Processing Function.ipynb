# %% [markdown]
# # Library

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import cv2 as cv

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar import image_processing
# %reload_ext autoreload

# %% [markdown]
# # Load data

# %%
img = cv.imread(f"E:\gitlab\machine-learning\image\images\sign.jpg")

# %% [markdown]
# # color patern

# %%
image_processing.kmean_color(img,9,stat="fix")

# %%
image_processing.kmean_color(img,9,stat="prop")

# %% [markdown]
# # High Dynamic Range (HDR) imaging

# %% [markdown]
# ## read image

# %%
exposures=[ 1/30.0, 0.25, 2.5, 15.0 ]

# %%
names = ["img_0.033.jpg", "img_0.25.jpg", "img_2.5.jpg", "img_15.jpg"]

# %%
hdrDebevec = image_processing.init_tonemap(names,exposures)
# Out:
# Reading images ...
# Aligning images ...
# Calculating Camera Response Function (CRF) ...
# Merging images into one HDR image ...
# 2021-07-07 17:57:24,558 [11376] WARNING  matplotlib.image:716: [JupyterRequire] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
res = image_processing.tonemap('drago',hdrDebevec)
# Out:
# Tonemaping using Drago's method ...
# 2021-07-07 17:57:26,029 [11376] WARNING  matplotlib.image:716: [JupyterRequire] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# saved ldr-Drago.jpg

# %%
res = image_processing.tonemap('durand',hdrDebevec)
# Out:
# Tonemaping using Durand's method ...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-37-7d9ec274080e> in <module>
# ----> 1 res = image_processing.tonemap('durand',hdrDebevec)
#
# E:\gitlab\custom-script\script\ursar.py in tonemap(algo, image)
#   14301             # sigma_color = 2.0f
#   14302             print("Tonemaping using Durand's method ... ")
# > 14303             tonemapDurand = cv2.xphoto.createTonemapDurand(1.5,4,1.0,1,1)
#   14304             ldrDurand = tonemapDurand.process(image)
#   14305             ldrDurand = 3 * ldrDurand
#
# error: OpenCV(4.3.0) ..\opencv_contrib\modules\xphoto\src\tonemap.cpp:125: error: (-213:The function/feature is not implemented) This algorithm is patented and is excluded in this configuration; Set OPENCV_ENABLE_NONFREE CMake option and rebuild the library in function 'cv::xphoto::createTonemapDurand'

# %%
res = image_processing.tonemap('Reinhard',hdrDebevec)
# Out:
# Tonemaping using Reinhard's method ...
# saved ldr-Reinhard.jpg

# %%
res = image_processing.tonemap('Mantiuk',hdrDebevec)
# Out:
# Tonemaping using Mantiuk's method ...
# 2021-07-07 17:58:09,093 [11376] WARNING  matplotlib.image:716: [JupyterRequire] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# saved ldr-Mantiuk.jpg

# %% [markdown]
# # Text detection

# %%
image_name = f"E:\gitlab\machine-learning\image\images\car_wash.png"
east = f"E:/gitlab/machine-learning/image/frozen_east_text_detection.pb"

# %%
f, ax = plt.subplots()
images = plt.imread(image_name)
ax.imshow(images)
ax.axis('off') #hide the axis
plt.tight_layout()
plt.show()

# %%
image_processing.text_detection(image_name,east)
# Out:
# origin shape
# width= 600, height= 338
# reshape shape
# width= 640, height= 320
# [INFO] loading EAST text detector...
# [INFO] text detection took 0.307066 seconds

# %%
image_name = f"E:\gitlab\machine-learning\image\images\lebron_james.jpg"
east = f"E:/gitlab/machine-learning/image/frozen_east_text_detection.pb"

# %%
f, ax = plt.subplots()
images = plt.imread(image_name)
ax.imshow(images)
ax.axis('off') #hide the axis
plt.tight_layout()
plt.show()

# %%
image_processing.text_detection(image_name,east)
# Out:
# origin shape
# width= 600, height= 500
# reshape shape
# width= 640, height= 320
# [INFO] loading EAST text detector...
# [INFO] text detection took 0.353996 seconds
# b) EVELANN

# %%
image_name = f"E:\gitlab\machine-learning\image\images\sign.jpg"
east = f"E:/gitlab/machine-learning/image/frozen_east_text_detection.pb"

# %%
f, ax = plt.subplots()
images = plt.imread(image_name)
ax.imshow(images)
ax.axis('off') #hide the axis
plt.tight_layout()
plt.show()

# %%
image_processing.text_detection(image_name,east)
# Out:
# origin shape
# width= 463, height= 400
# reshape shape
# width= 640, height= 320
# [INFO] loading EAST text detector...
# [INFO] text detection took 0.279000 seconds
