# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar import maps

# %reload_ext autoreload

# %% [markdown]
# # Dummy data

# %%
dummy = maps.dummy_data(10,15,100,10)

# %%
dummy
# Out:
# [[15.884950737641464, 101.14335246237039, 9.3113458406152],
#  [15.131345967169658, 99.59969098778556, 11.042772663658072],
#  [15.68684052544684, 99.36422779966848, 10.750289614056902],
#  [13.866282062004334, 100.67282601476148, 10.299081932024734],
#  [17.017693453322153, 101.26440250113637, 10.295192696417745],
#  [14.259255342268741, 99.4541889919036, 8.440012292145541],
#  [13.217721611225631, 100.15131580281597, 11.07419502316911],
#  [14.120719699255591, 99.33855287864621, 9.861390945231095],
#  [15.079258779365867, 99.49169653867868, 10.993419313542516],
#  [16.614474750123687, 99.7062603398474, 10.59125390342763]]

# %% [markdown]
# # heatmap plot

# %%
maps.heatmap(dummy,15,100,name_file='testing',tiles='OpenStreetMap')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps.heatmap(dummy,15,100,name_file='testing',tiles='stamentoner')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps.heatmap(dummy,15,100,name_file='testing',tiles='Stamenterrain',zoom=5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps.heatmap(dummy,15,100,name_file='testing',tiles='Stamenwatercolor',zoom=5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps.heatmap(dummy,15,100,name_file='testing',tiles='Cartodbpositron',zoom=5.5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps.heatmap(dummy,15,100,name_file='testing',tiles='Cartodbdark_matter',zoom=5.5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Map plot

# %%
df = pd.read_csv('E:/gitlab/machine-learning/dataset/geo_data.csv')
# url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
# country_shapes = f'{url}/world-countries.json'
global_polygons = gpd.read_file('global_polygons.geojson')
global_polygons.to_file('global_polygons.geojson', driver = 'GeoJSON')
medals_map = pd.merge(global_polygons, df, left_on='name',right_on='region')

# %%
maps.map_plot(medals_map,'region',"Total",["name","Total","Gold","Silver","Bronze"]
                        ,title=None,poly='Polygon')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # map plot marker

# %%
df = pd.read_csv("E:/gitlab/machine-learning/dataset/district wise population and centroids.csv")

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Longitude", "Latitude"],23,73)
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Longitude", "Latitude"],23,73,cluster=True)
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Longitude", "Latitude"],23,73,cluster=True,
                    icon_path='https://image.flaticon.com/icons/png/128/2968/2968342.png')
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Longitude", "Latitude"],23,73,cluster=True,
                    icon='podcast')
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Population in 2011","Longitude", "Latitude"],23,73,
                     popup=True,cluster = True)
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Population in 2011","Longitude", "Latitude"],23,73,
                     popup=True)
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
df1 = df[df.State == "Gujarat"][["Latitude", "Longitude"]][:3].values.tolist()
df2 = df[df.State == "Gujarat"][["Latitude", "Longitude"]][8:12].values.tolist()

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Population in 2011","Longitude", "Latitude"],23,73,
                     popup=True,poly=df1)
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Population in 2011","Longitude", "Latitude"],23,73,
                     popup=True,poly=df1)
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Population in 2011","Longitude", "Latitude"],23,73,
                     popup=True,poly=[df1,df2])
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
df1 = df[df.State == "Gujarat"][["Latitude", "Longitude"]][19:21].values.tolist()

# %%
df1
# Out:
# [[22.26133739279589, 73.49433010291594],
#  [20.44238231644259, 72.91485847983449]]

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Population in 2011","Longitude", "Latitude"],23,73,
                     popup=True,rectangle=df1)
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
df['Population in 2011'] = df['Population in 2011']//100

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Population in 2011","Longitude", "Latitude"],23,73,
                     mark_size=True)
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
maps.map_marker_plot(df[df.State == "Gujarat"],
                     ["District", "Population in 2011","Longitude", "Latitude"],23,73,
                     mark_size=True,cluster = True)
# Out:
# Map(center=[23, 73], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %% [markdown]
# # Indonesia map

# %%
df = pd.read_excel(f'E:\gitlab\machine-learning\dataset\indonesia map\Angka Partisipasi Sekolah.xlsx')
df.head()
# Out:
#          Province   7-12  13-15  16-18  19-24
# 0            Aceh  99.75  98.52  83.26  32.54
# 1  Sumatera Utara  99.41  96.89  77.67  25.75
# 2  Sumatera Barat  99.52  96.23  83.63  35.66
# 3            Riau  99.36  95.37  77.29  28.16
# 4           Jambi  99.70  96.42  71.97  23.32

# %%
maps.indonesia_map(df,'Province','19-24',values=True,cm='coolwarm',ranges=[0,50],
                   title='School Participations Rate for Age 19-24',
                   footnote='Source: Badan Pusat Statistik Indonesia')

# %% [markdown]
# # Kepler map

# %%
df = pd.read_csv(f'E:\gitlab\machine-learning\dataset\map dataset\Worldwide-Earthquake-database.csv')

# %%
df
# Out:
#         I_D FLAG_TSUNAMI  YEAR  MONTH   DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 0         1           No -2150    NaN   NaN   NaN     NaN                 NaN
# 1         2          Yes -2000    NaN   NaN   NaN     NaN    NaN          NaN
# 2         3           No -2000    NaN   NaN   NaN     NaN    NaN         18.0
# 3      5877          Yes -1610    NaN   NaN   NaN     NaN    NaN          NaN
# 4         8           No -1566    NaN   NaN   NaN     NaN                 NaN
# ...     ...          ...   ...    ...   ...   ...     ...    ...          ...
# 6188  10488           No  2020    4.0   1.0  12.0    23.0     27         10.0
# 6189  10490          Yes  2020    5.0   2.0  12.0    51.0      6         17.0
# 6190  10491           No  2020    5.0   7.0  20.0    18.0     22         10.0
# 6191  10494           No  2020    5.0  18.0  13.0    48.0      3         10.0
# 6192  10501          Yes  2020    5.0  29.0   5.0    30.0    NaN          NaN
#
#       EQ_PRIMARY  ...  TOTAL_MISSING  TOTAL_MISSING_DESCRIPTION  \
# 0            7.3  ...            NaN                        NaN
# 1            NaN  ...            NaN                        NaN
# 2            7.1  ...            NaN                        NaN
# 3            NaN  ...            NaN                        NaN
# 4            NaN  ...            NaN                        NaN
# ...          ...  ...            ...                        ...
# 6188         5.3  ...            NaN                        NaN
# 6189         6.6  ...            NaN                        NaN
# 6190         4.6  ...            NaN                        NaN
# 6191         5.2  ...            NaN                        NaN
# 6192         NaN  ...            NaN                        NaN
#
#       TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                NaN                         NaN
# 3                NaN                         NaN
# 4                NaN                         NaN
# ...              ...                         ...
# 6188             NaN                         NaN
# 6189             NaN                         NaN
# 6190            22.0                         1.0
# 6191            24.0                         1.0
# 6192             NaN                         NaN
#
#       TOTAL_DAMAGE_MILLIONS_DOLLARS  TOTAL_DAMAGE_DESCRIPTION  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       1.0
# 3                               NaN                       3.0
# 4                               NaN                       NaN
# ...                             ...                       ...
# 6188                          11.28                       3.0
# 6189                            NaN                       NaN
# 6190                            NaN                       NaN
# 6191                            NaN                       2.0
# 6192                            NaN                       NaN
#
#       TOTAL_HOUSES_DESTROYED TOTAL_HOUSES_DESTROYED_DESCRIPTION  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# 2                        NaN                                1.0
# 3                        NaN                                NaN
# 4                        NaN                                NaN
# ...                      ...                                ...
# 6188                     NaN                                NaN
# 6189                     NaN                                NaN
# 6190                     NaN                                NaN
# 6191                     NaN                                1.0
# 6192                     NaN                                NaN
#
#      TOTAL_HOUSES_DAMAGED TOTAL_HOUSES_DAMAGED_DESCRIPTION
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
# ...                   ...                              ...
# 6188                790.0                              3.0
# 6189                  NaN                              NaN
# 6190                  NaN                              NaN
# 6191                  NaN                              NaN
# 6192                  NaN                              NaN
#
# [6193 rows x 47 columns]

# %%
# lat and lon to numeric, errors converted to nan
df['LONGITUDE'] = pd.to_numeric(df.LONGITUDE, errors='coerce')
df['LATITUDE'] = pd.to_numeric(df.LATITUDE, errors='coerce')# drop rows with missing lat, lon, and intensity
df.dropna(subset=['LONGITUDE', 'LATITUDE', 'INTENSITY'], inplace=True)# convert tsunami flag from string to int
df['FLAG_TSUNAMI'] = [1 if i=='Yes' else 0 for i in df.FLAG_TSUNAMI.values]

# %%
maps.map_kepler(df,title='earthquakes',height=400)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'earthquakes': {'index': [1, 2, 4, 5, 9, 11, 14, 16, 18, 20, 23, 24, 25, 27, 35, 36, 37, 39, 41…

# %%
# https://opendata.vancouver.ca/explore/dataset/block-outlines/information/
block = gpd.read_file(f'E:/gitlab/machine-learning/dataset/map dataset/block-outlines.geojson')
block.dropna(inplace=True)
# https://opendata.vancouver.ca/explore/dataset/graffiti/information/
graffiti = gpd.read_file(f'E:/gitlab/machine-learning/dataset/map dataset/graffiti.geojson')
graffiti.dropna(inplace=True)
# join datasets - this will repeat the polygon for each point, and add the graffiti count to the blocks dataframe
graf_block = gpd.sjoin(block, graffiti, how='inner', op='contains')
# create new indexes
graf_block.reset_index(inplace=True)
graf_block = graf_block.dissolve(by='index', aggfunc='sum')
graf_block.head()
# Out:
#                                                 geometry  index_right  count
# index
# 1      POLYGON ((-123.10162 49.25362, -123.10148 49.2...        26288      8
# 4      POLYGON ((-123.09848 49.25919, -123.09849 49.2...        23300     10
# 5      POLYGON ((-123.09852 49.25795, -123.09851 49.2...          532      1
# 6      POLYGON ((-123.09854 49.25738, -123.09855 49.2...        15222      7
# 7      POLYGON ((-123.09857 49.25648, -123.09858 49.2...        12349      6

# %%
kepler_map = maps.map_kepler(graf_block,title='graffity',height=500)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
kepler_map
# Out:
# KeplerGl(data={'graffity': {'index': [1, 4, 5, 6, 7, 9, 10, 13, 16, 17, 18, 20, 21, 22, 27, 29, 42, 44, 45, 49…

# %%
kepler_map.save_to_html(file_name=f'graffity.html')
# Out:
# Map saved to graffity.html!
